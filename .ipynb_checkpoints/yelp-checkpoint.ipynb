# %% [markdown]
# # Yelp
# The objective is to automatically tags restaurants with multiple labels. The labels are,
# * 0: good_for_lunch
# * 1: good_for_dinner
# * 2: takes_reservations
# * 3: outdoor_seating
# * 4: restaurant_is_expensive
# * 5: has_alcohol
# * 6: has_table_service
# * 7: ambience_is_classy
# * 8: good_for_kids
#
# #### Strategy
# Since there are 9 different labels (tags), we'll train 9 different models, each dedicated to one label.
#
# We begin by importing some standard Python libraries

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
from tqdm import tqdm
import os
from skimage import io, novice
import pandas as pd
import matplotlib.pyplot as plt
import sys
import pickle
import cv2
from sklearn.model_selection import train_test_split 


TRAIN_DIR = './train_photos'
TEST_DIR = './test_photos'

TRAIN_SAVE = './train_img/'
TRAIN_LABEL = './train_label/'

TEST_SAVE = './test_img/'

IMG_SIZE = 100

# %% [markdown]
# ## Dataset
# * __train_photos__ - directory whihch contains photos of the training set
# * __test_photos__ - directory which contains photos of the test set
# * __train_photo_to_biz_ids.csv__ - maps the photo id to business id
# * __test_photo_to_biz_ids.csv__ - maps the photo id to business id
# * __train.csv__ - main training dataset. Includes the business id's, and their corresponding labels.
# * __sample_submission.csv__ - sample submission and the test dataset. This is the correct format for your predictions. It should include the business_id and the corresponding predicted labels.

# %%
training_imgs = list()
testing_imgs = list()
good_for_lunch = list()
good_for_dinner = list()
takes_reservations = list()
outdoor_seating = list()
restaurant_is_expensive = list()
has_alcohol = list()
has_table_service = list()
ambience_is_classy = list()
good_for_kids = list()

train_photo_to_biz_ids = pd.read_csv('train_photo_to_biz_ids.csv', names=['photo_id', 'business_id'])
train_photo_to_biz_ids = train_photo_to_biz_ids.set_index('photo_id')

test_photo_to_biz_ids = pd.read_csv('test_photo_to_biz.csv', names=['photo_id', 'business_id'])
test_photo_to_biz_ids = test_photo_to_biz_ids.set_index('photo_id')

biz_ids_to_labels = pd.read_csv('train.csv', names=['business_id', 'labels'])
biz_ids_to_labels = biz_ids_to_labels.set_index('business_id')

def read_images(training_imgs, testing_imgs, 
                good_for_lunch, good_for_dinner, 
                takes_reservations, outdoor_seating, 
                restaurant_is_expensive, has_alcohol, 
                has_table_service, ambience_is_classy, 
                good_for_kids, is_testing=False):
    i = 0
    f_id = 0
    
    if is_testing == False:
        print('Reading training data...')
        for img in tqdm(os.listdir(TRAIN_DIR)):
            f_name = os.path.splitext(img)[0]
            f_name = f_name.replace('.', '')
            f_name = f_name.replace('_', '')
            biz_id = train_photo_to_biz_ids.get_value(f_name, 'business_id')
            labels = str(biz_ids_to_labels.get_value(biz_id, 'labels'))
            
            one_hot(list(labels), 
                    good_for_lunch, 
                    good_for_dinner, 
                    takes_reservations, 
                    outdoor_seating, 
                    restaurant_is_expensive, 
                    has_alcohol, 
                    has_table_service, 
                    ambience_is_classy, 
                    good_for_kids)
            
            ext = os.path.splitext(img)[1]
            training_path = os.path.join(TRAIN_DIR, f_name + ext)
            img = cv2.imread(training_path)
                
            height, width = img.shape[:2]
            if height != IMG_SIZE or width != IMG_SIZE:
                img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                
#             average_color_per_row = np.average(img, axis=0)
#             average_color = np.average(average_color_per_row, axis=0)
                
            img = np.array(img) / 255.

#             img = cv2.dnn.blobFromImage(img, 1, (IMG_SIZE, IMG_SIZE), tuple(average_color))
            

            training_imgs.append(img)
            
            if (i == 23484 or i == 46968 or i == 70452 or 
                i == 93936 or i == 117420 or i == 140904 or 
                i == 164388 or i == 187872 or i == 211356 or 
                i == 234842 or i == 258326 or i == 281810 or 
                i == 305294 or i == 328778 or i == 352262 or 
                i == 375746 or i == 399230 or i == 422714 or 
                i == 446198 or i == 469682 or i == 493166 or 
                i == 516650 or i == 540134 or i == 563618):
                
                print('Saving training_' + str(f_id) + '.npy to disk')
                
                training_imgs = np.array(training_imgs)                
                np.save(TRAIN_SAVE + 'training_' + str(f_id) + '.npy', training_imgs)
                training_imgs = list()
                    
                good_for_lunch = np.array(good_for_lunch)
                np.save(TRAIN_LABEL + 'good_for_lunch_' + str(f_id) + '.npy', good_for_lunch)
                good_for_lunch = list()
        
                good_for_dinner = np.array(good_for_dinner)
                np.save(TRAIN_LABEL + 'good_for_dinner_' + str(f_id) + '.npy', good_for_dinner)
                good_for_dinner = list()
        
                takes_reservations = np.array(takes_reservations)
                np.save(TRAIN_LABEL + 'takes_reservations_' + str(f_id) + '.npy', takes_reservations)
                takes_reservations = list()
        
                outdoor_seating = np.array(outdoor_seating)
                np.save(TRAIN_LABEL + 'outdoor_seating_' + str(f_id) + '.npy', outdoor_seating)
                outdoor_seating = list()
        
                restaurant_is_expensive = np.array(restaurant_is_expensive)
                np.save(TRAIN_LABEL + 'restaurant_is_expensive_' + str(f_id) + '.npy', restaurant_is_expensive)
                restaurant_is_expensive = list()
        
                has_alcohol = np.array(has_alcohol)
                np.save(TRAIN_LABEL + 'has_alcohol_' + str(f_id) + '.npy', has_alcohol)
                has_alcohol = list()
        
                has_table_service = np.array(has_table_service)
                np.save(TRAIN_LABEL + 'has_table_service_' + str(f_id) + '.npy', has_table_service)
                has_table_service = list()
        
                ambience_is_classy = np.array(ambience_is_classy)
                np.save(TRAIN_LABEL + 'ambience_is_classy_' + str(f_id) + '.npy', ambience_is_classy)
                ambience_is_classy = list()
        
                good_for_kids = np.array(good_for_kids)
                np.save(TRAIN_LABEL + 'good_for_kids_' + str(f_id) + '.npy', good_for_kids)
                good_for_kids = list()
                
                f_id += 1
                
            i += 1            

    else:
        print('Reading testing data...')
        for img in tqdm(os.listdir(TEST_DIR)):
            f_name = os.path.splitext(img)[0]
            f_name = f_name.replace('.', '')
            f_name = f_name.replace('_', '')
            
            ext = os.path.splitext(img)[1]
            testing_path = os.path.join(TEST_DIR, f_name + ext)
            img = cv2.imread(testing_path)
                
            height, width = img.shape[:2]
            if height != IMG_SIZE or width != IMG_SIZE:
                img = cv2.resize(img, IMG_SIZE)                
#             img = np.array(img) / 255.
            
            average_color_per_row = numpy.average(img, axis=0)
            average_color = numpy.average(iaverage_color_per_rowmg, axis=0)
            
            img = cv2.dnn.blobFromImage(img, 1, (IMG_SIZE, IMG_SIZE), tuple(average_color))
            

            testing_imgs.append(img)
            
            if (i == 23484 or i == 46968 or i == 70452 or 
                i == 93936 or i == 117420 or i == 140904 or 
                i == 164388 or i == 187872 or i == 211356 or 
                i == 234842 or i == 258326 or i == 281810 or 
                i == 305294 or i == 328778 or i == 352262 or 
                i == 375746 or i == 399230 or i == 422714 or 
                i == 446198 or i == 469682 or i == 493166 or 
                i == 516650 or i == 540134 or i == 563618):
                
                print('Saving testing_' + str(f_id) + '.npy to disk')
                testing_imgs = np.array(testing_imgs)
                
                np.save(TEST_SAVE + 'testing_' + str(f_id) + '.npy', testing_imgs)
                testing_imgs = list()
            
                f_id += 1
                
            i += 1
        
def one_hot(labels, good_for_lunch, good_for_dinner, takes_reservations, outdoor_seating, 
            restaurant_is_expensive, has_alcohol, has_table_service, ambience_is_classy, good_for_kids):
    if '0' in labels:
        good_for_lunch.append(np.array([1, 0]))
    else:
        good_for_lunch.append(np.array([0, 1]))
        
    if '1' in labels:
        good_for_dinner.append(np.array([1, 0]))
    else:
        good_for_dinner.append(np.array([0, 1]))
        
    if '2' in labels:
        takes_reservations.append(np.array([1, 0]))
    else:
        takes_reservations.append(np.array([0, 1]))
        
    if '3' in labels:
        outdoor_seating.append(np.array([1, 0]))
    else:
        outdoor_seating.append(np.array([0, 1]))
        
    if '4' in labels:
        restaurant_is_expensive.append(np.array([1, 0]))
    else:
        restaurant_is_expensive.append(np.array([0, 1]))
        
    if '5' in labels:
        has_alcohol.append(np.array([1, 0]))
    else:
        has_alcohol.append(np.array([0, 1]))
        
    if '6' in labels:
        has_table_service.append(np.array([1, 0]))
    else:
        has_table_service.append(np.array([0, 1]))
        
    if '7' in labels:
        ambience_is_classy.append(np.array([1, 0]))
    else:
        ambience_is_classy.append(np.array([0, 1]))
        
    if '8' in labels:
        good_for_kids.append(np.array([1, 0]))
    else:
        good_for_kids.append(np.array([0, 1]))
        
def is_training_file_present():
    return (
        os.path.isfile(TRAIN_SAVE + 'training_0.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_1.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_2.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_3.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_4.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_5.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_6.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_7.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_8.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_9.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_10.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_11.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_12.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_13.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_14.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_15.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_16.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_17.npy') == False or 
        os.path.isfile(TRAIN_SAVE + 'training_18.npy') == False or os.path.isfile(TRAIN_SAVE + 'training_19.npy') == False
    )

def is_training_label_present():
    return (
        # check availability of good_for_lunch labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_lunch_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_lunch_19.npy') == False or 
        
        # check availability of good_for_dinner labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_dinner_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_dinner_19.npy') == False or 
        
        # check availability of takes_reservations labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'takes_reservations_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'takes_reservations_19.npy') == False or 
        
        # check availability of outdoor_seating labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'outdoor_seating_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'outdoor_seating_19.npy') == False or 
        
        # check availability of restaurant_is_expensive labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'restaurant_is_expensive_19.npy') == False or 
        
        # check availability of has_alcohol labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_alcohol_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_alcohol_19.npy') == False or 
        
        # check availability of has_table_service labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'has_table_service_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'has_table_service_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'has_table_service_19.npy') == False or 
        
        # check availability of ambience_is_classy labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'ambience_is_classy_19.npy') == False or 
        
        # check availability of good_for_kids labels in our ./train_label directory
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_0.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_1.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_2.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_3.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_4.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_5.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_6.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_7.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_8.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_9.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_10.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_11.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_12.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_13.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_14.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_15.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_16.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_17.npy') == False or 
        os.path.isfile(TRAIN_LABEL + 'good_for_kids_18.npy') == False or os.path.isfile(TRAIN_LABEL + 'good_for_kids_19.npy') == False
    )

def is_testing_file_present():
    return (
        os.path.isfile(TEST_SAVE + 'testing_0.npy') == False or os.path.isfile(TEST_SAVE + 'testing_1.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_2.npy') == False or os.path.isfile(TEST_SAVE + 'testing_3.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_4.npy') == False or os.path.isfile(TEST_SAVE + 'testing_5.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_6.npy') == False or os.path.isfile(TEST_SAVE + 'testing_7.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_8.npy') == False or os.path.isfile(TEST_SAVE + 'testing_9.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_10.npy') == False or os.path.isfile(TEST_SAVE + 'testing_11.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_12.npy') == False or os.path.isfile(TEST_SAVE + 'testing_13.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_14.npy') == False or os.path.isfile(TEST_SAVE + 'testing_15.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_16.npy') == False or os.path.isfile(TEST_SAVE + 'testing_17.npy') == False or 
        os.path.isfile(TEST_SAVE + 'testing_18.npy') == False or os.path.isfile(TEST_SAVE + 'testing_19.npy') == False
    )
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Insufficient RAM
# Due to insufficient memory, we are dividing the training data and their labels into 20 chunks. These chunks are saved as *__npy__* files on to disk.

# %%
if is_training_file_present() and is_training_label_present():
    
    read_images(training_imgs, testing_imgs, 
                good_for_lunch, good_for_dinner, 
                takes_reservations, outdoor_seating, 
                restaurant_is_expensive, has_alcohol, 
                has_table_service, ambience_is_classy, 
                good_for_kids)
else:
    # Load pickle files from disk
    
    print('Reading training data from pickle files....')

    
# if is_testing_file_present():
    
#     read_images(training_imgs, testing_imgs, 
#                 good_for_lunch, good_for_dinner, 
#                 takes_reservations, outdoor_seating, 
#                 restaurant_is_expensive, has_alcohol, 
#                 has_table_service, ambience_is_classy, 
#                 good_for_kids, is_testing=True)
    
# else:
#     # Load testing data from disk
#     print('Reading testing data from pickle files....')
    
#     pickle_in = pickle.open('testing.pickle', 'rb')
#     testing_imgs = pickle.load(pickle_in)
#     pickle_in.close()
# Out:
# Reading training data...
#   5%|▍         | 23466/469684 [01:52<35:41, 208.38it/s]
# Saving training_0.npy to disk
#  10%|▉         | 46963/469684 [04:24<39:41, 177.54it/s]
# Saving training_1.npy to disk
#  15%|█▍        | 70443/469684 [06:50<38:44, 171.78it/s]
# Saving training_2.npy to disk
#  20%|█▉        | 93929/469684 [09:12<36:48, 170.16it/s]
# Saving training_3.npy to disk
#  25%|██▍       | 117419/469684 [11:32<34:37, 169.55it/s]
# Saving training_4.npy to disk
#  30%|██▉       | 140888/469684 [13:50<32:18, 169.59it/s]
# Saving training_5.npy to disk
#  35%|███▍      | 164368/469684 [16:08<29:59, 169.69it/s]
# Saving training_6.npy to disk
#  40%|███▉      | 187851/469684 [18:24<27:36, 170.11it/s]
# Saving training_7.npy to disk
#  45%|████▍     | 211331/469684 [20:38<25:14, 170.58it/s]
# Saving training_8.npy to disk
#  50%|████▉     | 234820/469684 [22:52<22:53, 171.06it/s]
# Saving training_9.npy to disk
#  55%|█████▍    | 258313/469684 [25:09<20:34, 171.16it/s]
# Saving training_10.npy to disk
#  60%|█████▉    | 281809/469684 [27:28<18:18, 170.99it/s]
# Saving training_11.npy to disk
#  65%|██████▍   | 305294/469684 [29:45<16:01, 170.97it/s]
# Saving training_12.npy to disk
#  70%|██████▉   | 328762/469684 [32:02<13:43, 171.04it/s]
# Saving training_13.npy to disk
#  75%|███████▍  | 352253/469684 [34:21<11:27, 170.86it/s]
# Saving training_14.npy to disk
#  80%|███████▉  | 375735/469684 [36:39<09:09, 170.85it/s]
# Saving training_15.npy to disk
#  85%|████████▍ | 399210/469684 [38:57<06:52, 170.77it/s]
# Saving training_16.npy to disk
#  90%|████████▉ | 422701/469684 [41:15<04:35, 170.75it/s]
# Saving training_17.npy to disk
#  95%|█████████▍| 446180/469684 [43:32<02:17, 170.80it/s]
# Saving training_18.npy to disk
# 100%|█████████▉| 469667/469684 [45:51<00:00, 170.70it/s]
# Saving training_19.npy to disk
# 100%|██████████| 469684/469684 [45:59<00:00, 170.23it/s]

# %%
training_imgs = list()
training_imgs = np.load(TRAIN_SAVE + 'training_0.npy')

good_for_lunch = list()
good_for_lunch = np.load(TRAIN_LABEL + 'good_for_lunch_0.npy')
    
plt.imshow(training_imgs[5])
plt.show()
print(good_for_lunch[5])
total_imgs = training_imgs.shape[0]

training_imgs.shape
# Out:
# [0 1]
# (23485, 100, 100, 3)

# %% [markdown]
# ### Input
#
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement neural_net_image_input
#     * Return a TF Placeholder
#     * Set the shape using `image_shape` with batch size set to None.
#     * Name the TensorFlow placeholder "x" using the TensorFlow name parameter in the TF Placeholder.
# * Implement neural_net_label_input
#     * Return a TF Placeholder
#     * Set the shape using n_classes with batch size set to None.
#     * Name the TensorFlow placeholder "y" using the TensorFlow name parameter in the TF Placeholder.
# * Implement neural_net_keep_prob_input
#     * Return a TF Placeholder for dropout keep probability.
#     * Name the TensorFlow placeholder "keep_prob" using the TensorFlow name parameter in the TF Placeholder.
#     * These names will be used at the end of the project to load your saved model.
#
# Note: _None_ for shapes in TensorFlow allow for a dynamic size.

# %%
def neural_net_image_input(image_shape):
    return tf.placeholder(tf.float32, [None] + list(image_shape), 'x')

def neural_net_label_input(n_classes = 2):
    return tf.placeholder(tf.float32, (None, n_classes), 'y')

def neural_net_keep_prob_input():
    return tf.placeholder(tf.float32, None, 'keep_prob')

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function conv2d_maxpool to apply convolution then max pooling:
# * Create the weight and bias using conv_ksize, conv_num_outputs and the shape of x_tensor.
# * Apply a convolution to x_tensor using weight and conv_strides.
#     * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using pool_ksize and pool_strides.
#     * We recommend you use same padding, but you're welcome to use any padding.
#
# __Note__: You __can't__ use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for __this__ layer, but you can still use TensorFlow's Neural Network package. You may still use the shortcut option for all the __other__ layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize=(2,2), conv_strides=[1,1,1,1], pool_ksize=[1,2,2,1], pool_strides=[1,1,1,1]):
    dimension = x_tensor.get_shape().as_list()
    shape = list(conv_ksize + (dimension[-1],) + (conv_num_outputs,))
    weight = tf.Variable(tf.truncated_normal(shape, 0.0, 0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_layer = tf.nn.conv2d(x_tensor, weight, conv_strides, 'SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    conv_layer = tf.nn.max_pool(conv_layer, ksize=pool_ksize, strides=pool_strides, padding='SAME')
    
    return conv_layer

# %% [markdown]
# ### Flatten Layer
# Implement the flatten function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor. The output should be the shape (_Batch Size, Flattened Image Size_). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    dimension = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [-1, np.prod(dimension[1:])])

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (_Batch Size, num_outputs_). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)] packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    dimension = x_tensor.get_shape().as_list()
    shape = list((dimension[-1],) + (num_outputs,))
    weights = tf.Variable(tf.truncated_normal(shape, 0, 0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fully_conn = tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), bias))
    
    return fully_conn

# %% [markdown]
# ### Output Layer
# Implement the output function to apply a fully connected layer to `x_tensor` with the shape (_Batch Size, num_outputs_). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# __Note__: Activation, softmax, or cross entropy should __not__ be applied to this.

# %%
def output(x_tensor, num_outputs):
    dimension = x_tensor.get_shape().as_list()
    shape = list((dimension[-1],) + (num_outputs,))
    weight = tf.Variable(tf.truncated_normal(shape, 0 , 0.01))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    output = tf.add(tf.matmul(x_tensor, weight), bias)
    
    return output

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, x, and outputs logits. Use the layers you created above to create this model:
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    
#     model = conv2d_maxpool(x, conv_num_outputs=8)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=16)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=32)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=64)
#     model = tf.nn.dropout(model, keep_prob)
    
    model = conv2d_maxpool(x, conv_num_outputs=128)
    model = tf.nn.dropout(model, keep_prob)
    
    model = conv2d_maxpool(x, conv_num_outputs=192)
    model = tf.nn.dropout(model, keep_prob)
    
    model = conv2d_maxpool(x, conv_num_outputs=256)
    model = tf.nn.dropout(model, keep_prob)
    
    model = conv2d_maxpool(x, conv_num_outputs=320)
    model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=384)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=448)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=512)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=576)
#     model = tf.nn.dropout(model, keep_prob)
    
#     model = conv2d_maxpool(x, conv_num_outputs=640)
#     model = tf.nn.dropout(model, keep_prob)
    
    model = flatten(model)
    model = tf.nn.dropout(model, keep_prob)
    
#     model = fully_conn(model, 640)
#     model = fully_conn(model, 576)
    model = fully_conn(model, 320)
    model = fully_conn(model, 256)
    model = fully_conn(model, 128)
    model = fully_conn(model, 64)
    model = fully_conn(model, 32)
#     model = fully_conn(model, 16)
#     model = fully_conn(model, 8)
#     model = fully_conn(model, 4)
    
    model = output(model, 2)
    
    return model

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((IMG_SIZE, IMG_SIZE, 3))
y = neural_net_label_input()
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimization
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization. The optimization should use `optimizer` to optimize in session with a `feed_dict` of the following:
# * x for image input
# * y for labels
# * keep_prob for keep probability for dropout
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})

# %% [markdown]
# ## Show Stats
# Implement the function `print_stats` to print loss and validation accuracy. Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy. Use a keep probability of 1.0 to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy, val_features, val_labels):
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:0.7})
    valid_acc = session.run(accuracy, feed_dict={
        x: val_features,
        y: val_labels,
        keep_prob: 1.0
    })
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ## Hyperparameters
# Tune the following parameters:
# * Set epochs to the number of iterations until the network stops learning or start overfitting
# * Set batch_size to the highest number that your machine has memory for. Most people set them to common sizes of memory:
#     * 64
#     * 128
#     * 256
#     * ...
# * Set keep_probability to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 32
keep_probability = 0.3

# %% [markdown]
# ## Train on a Single Batch
# Instead of training the neural network on all the batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy. Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %% [markdown]
# ## Fully Train the Model
# Now that you got a good accuracy with a single batch, try it with all five batches.

# %%
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    
    # Training cycle
    for f_id in range(1, 20):
        for epoch in range(epochs):
            # Loop over all batches
            n_batches = total_imgs // batch_size
        
            i = 0
            index = batch_size
            for batch_i in range(1, n_batches + 1):
                batch_features = training_imgs[i:index]
                batch_labels = good_for_lunch[i:index]
            
                batch_features, val_features, batch_labels, val_labels = train_test_split(batch_features, 
                                                                                     batch_labels, test_size=0.3)
            
                if (batch_i == 1 or batch_i == 100 or batch_i == 200 or batch_i == 300 or batch_i == 400 or 
                    batch_i == 500 or batch_i == 600 or batch_i == 700 or batch_i == 730 or batch_i == 365) and (epoch == 0 or 
                                                                                               epoch % 10 == 0): 
                    print('Epoch {:>2}, Yelp Batch {}:  '.format(epoch + 1, batch_i), end='')
                    print_stats(sess, batch_features, batch_labels, cost, accuracy, val_features, val_labels)

                i += batch_size
                index += batch_size
                
        training_imgs = list()
        training_imgs = np.load(TRAIN_SAVE + 'training_' + str(f_id) + '.npy')

        good_for_lunch = list()
        good_for_lunch = np.load(TRAIN_LABEL + 'good_for_lunch_' + str(f_id) + '.npy')
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, Yelp Batch 1:  Loss:     0.7875 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 100:  Loss:     0.7227 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 200:  Loss:     0.7497 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 300:  Loss:     0.8030 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 400:  Loss:     0.8777 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 500:  Loss:     0.7012 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 600:  Loss:     0.8178 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 700:  Loss:     0.7377 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 730:  Loss:     0.8130 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 1:  Loss:     0.7892 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 100:  Loss:     0.7427 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 200:  Loss:     0.7798 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 300:  Loss:     0.7506 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 400:  Loss:     0.8369 Validation Accuracy: 0.000000
# Epoch 11, Yelp Batch 500:  Loss:     0.7140 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 600:  Loss:     0.8089 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 700:  Loss:     0.7699 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 730:  Loss:     0.7815 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 1:  Loss:     0.7659 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 100:  Loss:     0.7568 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 200:  Loss:     0.7756 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 300:  Loss:     0.7918 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 400:  Loss:     0.8249 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 500:  Loss:     0.7382 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 600:  Loss:     0.8063 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 700:  Loss:     0.7783 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 730:  Loss:     0.8087 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 1:  Loss:     0.7618 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 100:  Loss:     0.6836 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 200:  Loss:     0.8010 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 300:  Loss:     0.8511 Validation Accuracy: 0.500000
# Epoch 31, Yelp Batch 400:  Loss:     0.8101 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 500:  Loss:     0.8155 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 600:  Loss:     0.7893 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 700:  Loss:     0.7840 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 730:  Loss:     0.7885 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 1:  Loss:     0.7529 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 100:  Loss:     0.7028 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 200:  Loss:     0.7731 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 300:  Loss:     0.8016 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 400:  Loss:     0.8510 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 500:  Loss:     0.7506 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 600:  Loss:     0.8076 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 700:  Loss:     0.7933 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 730:  Loss:     0.7963 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 1:  Loss:     0.8044 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 100:  Loss:     0.7524 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 200:  Loss:     0.7502 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 300:  Loss:     0.7746 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 400:  Loss:     0.8080 Validation Accuracy: 0.000000
# Epoch 51, Yelp Batch 500:  Loss:     0.7512 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 600:  Loss:     0.8191 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 700:  Loss:     0.8257 Validation Accuracy: 0.500000
# Epoch 51, Yelp Batch 730:  Loss:     0.7577 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 1:  Loss:     0.7898 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 100:  Loss:     0.7186 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 200:  Loss:     0.7673 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 300:  Loss:     0.7675 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 400:  Loss:     0.8373 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 500:  Loss:     0.7553 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 600:  Loss:     0.7988 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 700:  Loss:     0.7344 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 730:  Loss:     0.7761 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 1:  Loss:     0.8804 Validation Accuracy: 0.500000
# Epoch 71, Yelp Batch 100:  Loss:     0.7272 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 200:  Loss:     0.8079 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 300:  Loss:     0.7271 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 400:  Loss:     0.8729 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 500:  Loss:     0.7838 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 600:  Loss:     0.7667 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 700:  Loss:     0.7671 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 730:  Loss:     0.8329 Validation Accuracy: 0.500000
# Epoch 81, Yelp Batch 1:  Loss:     0.7953 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 100:  Loss:     0.7435 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 200:  Loss:     0.8033 Validation Accuracy: 0.500000
# Epoch 81, Yelp Batch 300:  Loss:     0.7950 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 400:  Loss:     0.8832 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 500:  Loss:     0.7875 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 600:  Loss:     0.7804 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 700:  Loss:     0.7675 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 730:  Loss:     0.7992 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 1:  Loss:     0.7948 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 100:  Loss:     0.7211 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 200:  Loss:     0.7956 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 300:  Loss:     0.7870 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 400:  Loss:     0.8272 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 500:  Loss:     0.7432 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 600:  Loss:     0.8230 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 700:  Loss:     0.7816 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 730:  Loss:     0.8184 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 1:  Loss:     0.7937 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 100:  Loss:     0.8460 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 200:  Loss:     0.7855 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 300:  Loss:     0.8232 Validation Accuracy: 0.600000
# Epoch  1, Yelp Batch 400:  Loss:     0.7738 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 500:  Loss:     0.8386 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 600:  Loss:     0.8408 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 700:  Loss:     0.7523 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 730:  Loss:     0.7384 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 1:  Loss:     0.7788 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 100:  Loss:     0.8083 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 200:  Loss:     0.7676 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 300:  Loss:     0.7624 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 400:  Loss:     0.8240 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 500:  Loss:     0.8097 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 600:  Loss:     0.8037 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 700:  Loss:     0.7699 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 730:  Loss:     0.7749 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 1:  Loss:     0.8137 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 100:  Loss:     0.8473 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 200:  Loss:     0.7256 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 300:  Loss:     0.7624 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 400:  Loss:     0.8224 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 500:  Loss:     0.8187 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 600:  Loss:     0.7939 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 700:  Loss:     0.8263 Validation Accuracy: 0.500000
# Epoch 21, Yelp Batch 730:  Loss:     0.7816 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 1:  Loss:     0.7932 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 100:  Loss:     0.8563 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 200:  Loss:     0.7579 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 300:  Loss:     0.8151 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 400:  Loss:     0.8071 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 500:  Loss:     0.7912 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 600:  Loss:     0.8051 Validation Accuracy: 0.000000
# Epoch 31, Yelp Batch 700:  Loss:     0.7406 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 730:  Loss:     0.7813 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 1:  Loss:     0.8097 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 100:  Loss:     0.8176 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 200:  Loss:     0.8059 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 300:  Loss:     0.7459 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 400:  Loss:     0.7864 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 500:  Loss:     0.7833 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.8152 Validation Accuracy: 0.000000
# Epoch 41, Yelp Batch 700:  Loss:     0.7850 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 730:  Loss:     0.7326 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 1:  Loss:     0.8498 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 100:  Loss:     0.8057 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 200:  Loss:     0.7718 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 300:  Loss:     0.8022 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 400:  Loss:     0.8139 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 500:  Loss:     0.7624 Validation Accuracy: 0.000000
# Epoch 51, Yelp Batch 600:  Loss:     0.8489 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 700:  Loss:     0.7634 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 730:  Loss:     0.7343 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 1:  Loss:     0.8176 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 100:  Loss:     0.8026 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 200:  Loss:     0.7859 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 300:  Loss:     0.8112 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 400:  Loss:     0.7972 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 500:  Loss:     0.7877 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 600:  Loss:     0.8437 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 700:  Loss:     0.7739 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 730:  Loss:     0.8096 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 1:  Loss:     0.7819 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 100:  Loss:     0.8224 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 200:  Loss:     0.7895 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 300:  Loss:     0.7862 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 400:  Loss:     0.8295 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 500:  Loss:     0.8430 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 600:  Loss:     0.8247 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 700:  Loss:     0.7775 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 730:  Loss:     0.7824 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 1:  Loss:     0.8201 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 100:  Loss:     0.8588 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 200:  Loss:     0.7499 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 300:  Loss:     0.7555 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 400:  Loss:     0.8005 Validation Accuracy: 0.000000
# Epoch 81, Yelp Batch 500:  Loss:     0.7858 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 600:  Loss:     0.8239 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 700:  Loss:     0.7988 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 730:  Loss:     0.8026 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 1:  Loss:     0.8202 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 100:  Loss:     0.8301 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 200:  Loss:     0.7607 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 300:  Loss:     0.8083 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 400:  Loss:     0.8003 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 500:  Loss:     0.8255 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 600:  Loss:     0.8401 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 700:  Loss:     0.8155 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 730:  Loss:     0.7872 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 1:  Loss:     0.8118 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 100:  Loss:     0.8459 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 200:  Loss:     0.8212 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 300:  Loss:     0.8180 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 400:  Loss:     0.8430 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 500:  Loss:     0.8199 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 600:  Loss:     0.7875 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 700:  Loss:     0.7481 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 730:  Loss:     0.7475 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 1:  Loss:     0.8077 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 100:  Loss:     0.8263 Validation Accuracy: 0.000000
# Epoch 11, Yelp Batch 200:  Loss:     0.7646 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 300:  Loss:     0.7738 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 400:  Loss:     0.8347 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 500:  Loss:     0.8026 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 600:  Loss:     0.7645 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 700:  Loss:     0.7673 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 730:  Loss:     0.7758 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 1:  Loss:     0.8281 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 100:  Loss:     0.8102 Validation Accuracy: 0.000000
# Epoch 21, Yelp Batch 200:  Loss:     0.7954 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 300:  Loss:     0.8173 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 400:  Loss:     0.7702 Validation Accuracy: 0.000000
# Epoch 21, Yelp Batch 500:  Loss:     0.7739 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 600:  Loss:     0.7797 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 700:  Loss:     0.7979 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 730:  Loss:     0.7929 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 1:  Loss:     0.8189 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 100:  Loss:     0.8152 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 200:  Loss:     0.8196 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 300:  Loss:     0.7534 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 400:  Loss:     0.8565 Validation Accuracy: 0.000000
# Epoch 31, Yelp Batch 500:  Loss:     0.7932 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 600:  Loss:     0.8185 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 700:  Loss:     0.7962 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 730:  Loss:     0.7621 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 1:  Loss:     0.8489 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 100:  Loss:     0.7870 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 200:  Loss:     0.8162 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 300:  Loss:     0.8039 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 400:  Loss:     0.8681 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 500:  Loss:     0.8452 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 600:  Loss:     0.7814 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 700:  Loss:     0.8188 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 730:  Loss:     0.7797 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 1:  Loss:     0.8208 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 100:  Loss:     0.8287 Validation Accuracy: 0.000000
# Epoch 51, Yelp Batch 200:  Loss:     0.7692 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 300:  Loss:     0.7600 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 400:  Loss:     0.7891 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 500:  Loss:     0.7738 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 600:  Loss:     0.7766 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 700:  Loss:     0.8175 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 730:  Loss:     0.7515 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 1:  Loss:     0.8026 Validation Accuracy: 0.400000
# Epoch 61, Yelp Batch 100:  Loss:     0.8331 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 200:  Loss:     0.8357 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 300:  Loss:     0.7974 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 400:  Loss:     0.8081 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 500:  Loss:     0.7998 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 600:  Loss:     0.7353 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 700:  Loss:     0.7772 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 730:  Loss:     0.7867 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 1:  Loss:     0.7661 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 100:  Loss:     0.9111 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 200:  Loss:     0.8142 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 300:  Loss:     0.7611 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 400:  Loss:     0.8021 Validation Accuracy: 0.000000
# Epoch 71, Yelp Batch 500:  Loss:     0.8008 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 600:  Loss:     0.8075 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 700:  Loss:     0.7804 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 730:  Loss:     0.7766 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 1:  Loss:     0.8218 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 100:  Loss:     0.8398 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 200:  Loss:     0.7676 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 300:  Loss:     0.7841 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 400:  Loss:     0.8003 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 500:  Loss:     0.7305 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 600:  Loss:     0.7607 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 700:  Loss:     0.7543 Validation Accuracy: 0.000000
# Epoch 81, Yelp Batch 730:  Loss:     0.8256 Validation Accuracy: 0.600000
# Epoch 91, Yelp Batch 1:  Loss:     0.8176 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 100:  Loss:     0.8766 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 200:  Loss:     0.7808 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 300:  Loss:     0.7813 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 400:  Loss:     0.8446 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 500:  Loss:     0.8038 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 600:  Loss:     0.8290 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 700:  Loss:     0.8207 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 730:  Loss:     0.7630 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 1:  Loss:     0.7965 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 100:  Loss:     0.8218 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 200:  Loss:     0.7853 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 300:  Loss:     0.8413 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 400:  Loss:     0.8123 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 500:  Loss:     0.7916 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 600:  Loss:     0.8311 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 700:  Loss:     0.7572 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 730:  Loss:     0.8100 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 1:  Loss:     0.7576 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 100:  Loss:     0.7431 Validation Accuracy: 0.000000
# Epoch 11, Yelp Batch 200:  Loss:     0.7926 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 300:  Loss:     0.7931 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 400:  Loss:     0.8003 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 500:  Loss:     0.7812 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 600:  Loss:     0.7983 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 700:  Loss:     0.8119 Validation Accuracy: 0.600000
# Epoch 11, Yelp Batch 730:  Loss:     0.8279 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 1:  Loss:     0.7637 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 100:  Loss:     0.8220 Validation Accuracy: 0.500000
# Epoch 21, Yelp Batch 200:  Loss:     0.7917 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 300:  Loss:     0.7897 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 400:  Loss:     0.8617 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 500:  Loss:     0.7861 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 600:  Loss:     0.8275 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 700:  Loss:     0.7405 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 730:  Loss:     0.8480 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 1:  Loss:     0.7788 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 100:  Loss:     0.7741 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 200:  Loss:     0.7662 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 300:  Loss:     0.7954 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 400:  Loss:     0.8320 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 500:  Loss:     0.7832 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 600:  Loss:     0.8291 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 700:  Loss:     0.7300 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 730:  Loss:     0.8325 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 1:  Loss:     0.7965 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 100:  Loss:     0.7414 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 200:  Loss:     0.8110 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 300:  Loss:     0.7918 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 400:  Loss:     0.7941 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 500:  Loss:     0.8007 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.8210 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 700:  Loss:     0.7628 Validation Accuracy: 0.600000
# Epoch 41, Yelp Batch 730:  Loss:     0.8703 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 1:  Loss:     0.8103 Validation Accuracy: 0.500000
# Epoch 51, Yelp Batch 100:  Loss:     0.8060 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 200:  Loss:     0.7193 Validation Accuracy: 0.000000
# Epoch 51, Yelp Batch 300:  Loss:     0.7878 Validation Accuracy: 0.000000
# Epoch 51, Yelp Batch 400:  Loss:     0.8425 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 500:  Loss:     0.8483 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 600:  Loss:     0.8284 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 700:  Loss:     0.7323 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 730:  Loss:     0.8240 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 1:  Loss:     0.7842 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 100:  Loss:     0.7835 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 200:  Loss:     0.8340 Validation Accuracy: 0.400000
# Epoch 61, Yelp Batch 300:  Loss:     0.7963 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 400:  Loss:     0.8671 Validation Accuracy: 0.400000
# Epoch 61, Yelp Batch 500:  Loss:     0.7894 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 600:  Loss:     0.8037 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 700:  Loss:     0.7255 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 730:  Loss:     0.8439 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 1:  Loss:     0.7880 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 100:  Loss:     0.7597 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 200:  Loss:     0.8334 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 300:  Loss:     0.8048 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 400:  Loss:     0.8579 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 500:  Loss:     0.8636 Validation Accuracy: 0.500000
# Epoch 71, Yelp Batch 600:  Loss:     0.8219 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 700:  Loss:     0.7588 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 730:  Loss:     0.8378 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 1:  Loss:     0.7554 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 100:  Loss:     0.8232 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 200:  Loss:     0.7652 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 300:  Loss:     0.8155 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 400:  Loss:     0.8207 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 500:  Loss:     0.8335 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 600:  Loss:     0.8331 Validation Accuracy: 0.500000
# Epoch 81, Yelp Batch 700:  Loss:     0.8164 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 730:  Loss:     0.8196 Validation Accuracy: 0.000000
# Epoch 91, Yelp Batch 1:  Loss:     0.7915 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 100:  Loss:     0.8129 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 200:  Loss:     0.8077 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 300:  Loss:     0.8050 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 400:  Loss:     0.7876 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 500:  Loss:     0.8636 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 600:  Loss:     0.8175 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 700:  Loss:     0.7386 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 730:  Loss:     0.8574 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 1:  Loss:     0.7901 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 100:  Loss:     0.7439 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 200:  Loss:     0.7927 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 300:  Loss:     0.7956 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 400:  Loss:     0.7258 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 500:  Loss:     0.8024 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 600:  Loss:     0.8051 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 700:  Loss:     0.7808 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 730:  Loss:     0.7727 Validation Accuracy: 0.000000
# Epoch 11, Yelp Batch 1:  Loss:     0.8128 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 100:  Loss:     0.7489 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 200:  Loss:     0.8227 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 300:  Loss:     0.7549 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 400:  Loss:     0.7597 Validation Accuracy: 0.500000
# Epoch 11, Yelp Batch 500:  Loss:     0.7947 Validation Accuracy: 0.500000
# Epoch 11, Yelp Batch 600:  Loss:     0.8090 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 700:  Loss:     0.7884 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 730:  Loss:     0.8063 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 1:  Loss:     0.8459 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 100:  Loss:     0.8165 Validation Accuracy: 0.500000
# Epoch 21, Yelp Batch 200:  Loss:     0.8169 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 300:  Loss:     0.8295 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 400:  Loss:     0.6879 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 500:  Loss:     0.7698 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 600:  Loss:     0.7822 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 700:  Loss:     0.7395 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 730:  Loss:     0.8235 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 1:  Loss:     0.8316 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 100:  Loss:     0.7418 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 200:  Loss:     0.8172 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 300:  Loss:     0.7962 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 400:  Loss:     0.7563 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 500:  Loss:     0.7944 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 600:  Loss:     0.7895 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 700:  Loss:     0.7765 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 730:  Loss:     0.7734 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 1:  Loss:     0.8284 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 100:  Loss:     0.7936 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 200:  Loss:     0.7962 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 300:  Loss:     0.8150 Validation Accuracy: 0.000000
# Epoch 41, Yelp Batch 400:  Loss:     0.7564 Validation Accuracy: 0.500000
# Epoch 41, Yelp Batch 500:  Loss:     0.7767 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.7979 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 700:  Loss:     0.7596 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 730:  Loss:     0.7657 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 1:  Loss:     0.8105 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 100:  Loss:     0.8103 Validation Accuracy: 0.500000
# Epoch 51, Yelp Batch 200:  Loss:     0.8302 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 300:  Loss:     0.8856 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 400:  Loss:     0.7603 Validation Accuracy: 0.500000
# Epoch 51, Yelp Batch 500:  Loss:     0.7562 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 600:  Loss:     0.7937 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 700:  Loss:     0.7469 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 730:  Loss:     0.8161 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 1:  Loss:     0.7817 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 100:  Loss:     0.7735 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 200:  Loss:     0.8038 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 300:  Loss:     0.8554 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 400:  Loss:     0.6973 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 500:  Loss:     0.8050 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 600:  Loss:     0.7905 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 700:  Loss:     0.7462 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 730:  Loss:     0.8031 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 1:  Loss:     0.8295 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 100:  Loss:     0.7595 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 200:  Loss:     0.7884 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 300:  Loss:     0.8436 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 400:  Loss:     0.7387 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 500:  Loss:     0.8463 Validation Accuracy: 0.500000
# Epoch 71, Yelp Batch 600:  Loss:     0.8111 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 700:  Loss:     0.7890 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 730:  Loss:     0.7998 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 1:  Loss:     0.8215 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 100:  Loss:     0.7823 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 200:  Loss:     0.8176 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 300:  Loss:     0.8260 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 400:  Loss:     0.7868 Validation Accuracy: 0.500000
# Epoch 81, Yelp Batch 500:  Loss:     0.7962 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 600:  Loss:     0.8330 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 700:  Loss:     0.7479 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 730:  Loss:     0.7606 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 1:  Loss:     0.8297 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 100:  Loss:     0.7682 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 200:  Loss:     0.8692 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 300:  Loss:     0.8198 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 400:  Loss:     0.8029 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 500:  Loss:     0.7713 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 600:  Loss:     0.8256 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 700:  Loss:     0.7588 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 730:  Loss:     0.8049 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 1:  Loss:     0.8212 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 100:  Loss:     0.8048 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 200:  Loss:     0.7597 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 300:  Loss:     0.7932 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 400:  Loss:     0.7555 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 500:  Loss:     0.7985 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 600:  Loss:     0.8629 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 700:  Loss:     0.7079 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 730:  Loss:     0.7759 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 1:  Loss:     0.8097 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 100:  Loss:     0.8389 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 200:  Loss:     0.7676 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 300:  Loss:     0.8114 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 400:  Loss:     0.7555 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 500:  Loss:     0.7163 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 600:  Loss:     0.8300 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 700:  Loss:     0.7701 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 730:  Loss:     0.7399 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 1:  Loss:     0.8282 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 100:  Loss:     0.8341 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 200:  Loss:     0.7803 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 300:  Loss:     0.7880 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 400:  Loss:     0.7885 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 500:  Loss:     0.7385 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 600:  Loss:     0.7332 Validation Accuracy: 0.000000
# Epoch 21, Yelp Batch 700:  Loss:     0.7831 Validation Accuracy: 0.500000
# Epoch 21, Yelp Batch 730:  Loss:     0.8281 Validation Accuracy: 0.500000
# Epoch 31, Yelp Batch 1:  Loss:     0.8014 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 100:  Loss:     0.8772 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 200:  Loss:     0.7588 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 300:  Loss:     0.7717 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 400:  Loss:     0.7159 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 500:  Loss:     0.8045 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 600:  Loss:     0.7994 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 700:  Loss:     0.7330 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 730:  Loss:     0.7998 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 1:  Loss:     0.8003 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 100:  Loss:     0.8729 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 200:  Loss:     0.8222 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 300:  Loss:     0.8436 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 400:  Loss:     0.7495 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 500:  Loss:     0.7804 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.8128 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 700:  Loss:     0.7583 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 730:  Loss:     0.8002 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 1:  Loss:     0.7598 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 100:  Loss:     0.8167 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 200:  Loss:     0.7918 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 300:  Loss:     0.8150 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 400:  Loss:     0.7926 Validation Accuracy: 0.500000
# Epoch 51, Yelp Batch 500:  Loss:     0.7889 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 600:  Loss:     0.8728 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 700:  Loss:     0.7376 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 730:  Loss:     0.8013 Validation Accuracy: 0.600000
# Epoch 61, Yelp Batch 1:  Loss:     0.7907 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 100:  Loss:     0.8426 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 200:  Loss:     0.7932 Validation Accuracy: 0.500000
# Epoch 61, Yelp Batch 300:  Loss:     0.7785 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 400:  Loss:     0.7763 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 500:  Loss:     0.7507 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 600:  Loss:     0.8396 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 700:  Loss:     0.7636 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 730:  Loss:     0.7962 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 1:  Loss:     0.8404 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 100:  Loss:     0.7983 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 200:  Loss:     0.8230 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 300:  Loss:     0.7876 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 400:  Loss:     0.7799 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 500:  Loss:     0.7602 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 600:  Loss:     0.8371 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 700:  Loss:     0.7843 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 730:  Loss:     0.7755 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 1:  Loss:     0.8638 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 100:  Loss:     0.7579 Validation Accuracy: 0.000000
# Epoch 81, Yelp Batch 200:  Loss:     0.8247 Validation Accuracy: 0.500000
# Epoch 81, Yelp Batch 300:  Loss:     0.8156 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 400:  Loss:     0.7296 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 500:  Loss:     0.7768 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 600:  Loss:     0.8093 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 700:  Loss:     0.7836 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 730:  Loss:     0.7932 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 1:  Loss:     0.8088 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 100:  Loss:     0.8054 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 200:  Loss:     0.7939 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 300:  Loss:     0.7599 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 400:  Loss:     0.7822 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 500:  Loss:     0.7635 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 600:  Loss:     0.7746 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 700:  Loss:     0.7514 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 730:  Loss:     0.8065 Validation Accuracy: 0.500000
# Epoch  1, Yelp Batch 1:  Loss:     0.8354 Validation Accuracy: 0.500000
# Epoch  1, Yelp Batch 100:  Loss:     0.7900 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 200:  Loss:     0.7180 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 300:  Loss:     0.8236 Validation Accuracy: 0.400000
# Epoch  1, Yelp Batch 400:  Loss:     0.7929 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 500:  Loss:     0.7658 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 600:  Loss:     0.8155 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 700:  Loss:     0.8526 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 730:  Loss:     0.8019 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 1:  Loss:     0.7965 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 100:  Loss:     0.8188 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 200:  Loss:     0.7334 Validation Accuracy: 0.500000
# Epoch 11, Yelp Batch 300:  Loss:     0.7809 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 400:  Loss:     0.8236 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 500:  Loss:     0.7621 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 600:  Loss:     0.7859 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 700:  Loss:     0.8901 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 730:  Loss:     0.7677 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 1:  Loss:     0.8271 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 100:  Loss:     0.7957 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 200:  Loss:     0.7063 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 300:  Loss:     0.8081 Validation Accuracy: 0.500000
# Epoch 21, Yelp Batch 400:  Loss:     0.7842 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 500:  Loss:     0.7833 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 600:  Loss:     0.7489 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 700:  Loss:     0.8410 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 730:  Loss:     0.7694 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 1:  Loss:     0.7907 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 100:  Loss:     0.7950 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 200:  Loss:     0.7159 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 300:  Loss:     0.8070 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 400:  Loss:     0.7982 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 500:  Loss:     0.7727 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 600:  Loss:     0.7786 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 700:  Loss:     0.8518 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 730:  Loss:     0.8195 Validation Accuracy: 0.400000
# Epoch 41, Yelp Batch 1:  Loss:     0.8543 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 100:  Loss:     0.7829 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 200:  Loss:     0.7005 Validation Accuracy: 0.500000
# Epoch 41, Yelp Batch 300:  Loss:     0.7795 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 400:  Loss:     0.7591 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 500:  Loss:     0.7396 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.7654 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 700:  Loss:     0.8396 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 730:  Loss:     0.8171 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 1:  Loss:     0.8337 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 100:  Loss:     0.8669 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 200:  Loss:     0.7486 Validation Accuracy: 0.600000
# Epoch 51, Yelp Batch 300:  Loss:     0.7482 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 400:  Loss:     0.8331 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 500:  Loss:     0.7626 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 600:  Loss:     0.8119 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 700:  Loss:     0.8227 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 730:  Loss:     0.8303 Validation Accuracy: 0.400000
# Epoch 61, Yelp Batch 1:  Loss:     0.7638 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 100:  Loss:     0.8110 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 200:  Loss:     0.7758 Validation Accuracy: 0.600000
# Epoch 61, Yelp Batch 300:  Loss:     0.7849 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 400:  Loss:     0.8527 Validation Accuracy: 0.400000
# Epoch 61, Yelp Batch 500:  Loss:     0.7282 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 600:  Loss:     0.7726 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 700:  Loss:     0.9121 Validation Accuracy: 0.400000
# Epoch 61, Yelp Batch 730:  Loss:     0.7816 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 1:  Loss:     0.7936 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 100:  Loss:     0.8291 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 200:  Loss:     0.7039 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 300:  Loss:     0.8058 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 400:  Loss:     0.8231 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 500:  Loss:     0.7321 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 600:  Loss:     0.7942 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 700:  Loss:     0.8396 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 730:  Loss:     0.7916 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 1:  Loss:     0.7710 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 100:  Loss:     0.7998 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 200:  Loss:     0.7044 Validation Accuracy: 0.600000
# Epoch 81, Yelp Batch 300:  Loss:     0.7584 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 400:  Loss:     0.7681 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 500:  Loss:     0.7663 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 600:  Loss:     0.7740 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 700:  Loss:     0.8124 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 730:  Loss:     0.8251 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 1:  Loss:     0.8372 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 100:  Loss:     0.7887 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 200:  Loss:     0.7438 Validation Accuracy: 0.700000
# Epoch 91, Yelp Batch 300:  Loss:     0.7804 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 400:  Loss:     0.8149 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 500:  Loss:     0.8075 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 600:  Loss:     0.7293 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 700:  Loss:     0.8696 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 730:  Loss:     0.8231 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 1:  Loss:     0.6910 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 100:  Loss:     0.8216 Validation Accuracy: 0.500000
# Epoch  1, Yelp Batch 200:  Loss:     0.7912 Validation Accuracy: 0.000000
# Epoch  1, Yelp Batch 300:  Loss:     0.8035 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 400:  Loss:     0.7913 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 500:  Loss:     0.8181 Validation Accuracy: 0.500000
# Epoch  1, Yelp Batch 600:  Loss:     0.8334 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 700:  Loss:     0.8377 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 730:  Loss:     0.8489 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 1:  Loss:     0.7547 Validation Accuracy: 0.500000
# Epoch 11, Yelp Batch 100:  Loss:     0.8279 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 200:  Loss:     0.7948 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 300:  Loss:     0.7705 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 400:  Loss:     0.8514 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 500:  Loss:     0.7966 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 600:  Loss:     0.8245 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 700:  Loss:     0.8286 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 730:  Loss:     0.8186 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 1:  Loss:     0.7420 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 100:  Loss:     0.8057 Validation Accuracy: 0.200000
# ...
# Epoch 61, Yelp Batch 1:  Loss:     0.8284 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 100:  Loss:     0.7535 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 200:  Loss:     0.8227 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 300:  Loss:     0.7705 Validation Accuracy: 0.300000
# Epoch 61, Yelp Batch 400:  Loss:     0.7784 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 500:  Loss:     0.7572 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 600:  Loss:     0.7572 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 700:  Loss:     0.7759 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 730:  Loss:     0.8072 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 1:  Loss:     0.7827 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 100:  Loss:     0.7509 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 200:  Loss:     0.8127 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 300:  Loss:     0.7912 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 400:  Loss:     0.7638 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 500:  Loss:     0.8223 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 600:  Loss:     0.7873 Validation Accuracy: 0.400000
# Epoch 71, Yelp Batch 700:  Loss:     0.8034 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 730:  Loss:     0.8037 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 1:  Loss:     0.7967 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 100:  Loss:     0.7902 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 200:  Loss:     0.7753 Validation Accuracy: 0.000000
# Epoch 81, Yelp Batch 300:  Loss:     0.7937 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 400:  Loss:     0.7691 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 500:  Loss:     0.7708 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 600:  Loss:     0.7427 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 700:  Loss:     0.8405 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 730:  Loss:     0.7317 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 1:  Loss:     0.7996 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 100:  Loss:     0.7670 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 200:  Loss:     0.8192 Validation Accuracy: 0.000000
# Epoch 91, Yelp Batch 300:  Loss:     0.7713 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 400:  Loss:     0.7887 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 500:  Loss:     0.8898 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 600:  Loss:     0.7242 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 700:  Loss:     0.8188 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 730:  Loss:     0.7527 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 1:  Loss:     0.7669 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 100:  Loss:     0.7904 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 200:  Loss:     0.8131 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 300:  Loss:     0.7940 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 400:  Loss:     0.7735 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 500:  Loss:     0.8402 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 600:  Loss:     0.8138 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 700:  Loss:     0.8775 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 730:  Loss:     0.8009 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 1:  Loss:     0.7222 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 100:  Loss:     0.7935 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 200:  Loss:     0.8473 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 300:  Loss:     0.8800 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 400:  Loss:     0.7873 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 500:  Loss:     0.8191 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 600:  Loss:     0.7771 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 700:  Loss:     0.8837 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 730:  Loss:     0.8217 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 1:  Loss:     0.7921 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 100:  Loss:     0.7684 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 200:  Loss:     0.8114 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 300:  Loss:     0.7805 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 400:  Loss:     0.8355 Validation Accuracy: 0.500000
# Epoch 21, Yelp Batch 500:  Loss:     0.8265 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 600:  Loss:     0.7877 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 700:  Loss:     0.8511 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 730:  Loss:     0.8077 Validation Accuracy: 0.400000
# Epoch 31, Yelp Batch 1:  Loss:     0.7767 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 100:  Loss:     0.7644 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 200:  Loss:     0.7735 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 300:  Loss:     0.8081 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 400:  Loss:     0.7972 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 500:  Loss:     0.8204 Validation Accuracy: 0.300000
# Epoch 31, Yelp Batch 600:  Loss:     0.7872 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 700:  Loss:     0.8106 Validation Accuracy: 0.000000
# Epoch 31, Yelp Batch 730:  Loss:     0.7175 Validation Accuracy: 0.000000
# Epoch 41, Yelp Batch 1:  Loss:     0.8116 Validation Accuracy: 0.500000
# Epoch 41, Yelp Batch 100:  Loss:     0.7791 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 200:  Loss:     0.7911 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 300:  Loss:     0.8680 Validation Accuracy: 0.500000
# Epoch 41, Yelp Batch 400:  Loss:     0.8785 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 500:  Loss:     0.7741 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.8109 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 700:  Loss:     0.8488 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 730:  Loss:     0.8167 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 1:  Loss:     0.8185 Validation Accuracy: 0.600000
# Epoch 51, Yelp Batch 100:  Loss:     0.7758 Validation Accuracy: 0.400000
# Epoch 51, Yelp Batch 200:  Loss:     0.8462 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 300:  Loss:     0.8469 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 400:  Loss:     0.8486 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 500:  Loss:     0.8029 Validation Accuracy: 0.100000
# Epoch 51, Yelp Batch 600:  Loss:     0.7753 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 700:  Loss:     0.8382 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 730:  Loss:     0.7947 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 1:  Loss:     0.7635 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 100:  Loss:     0.7778 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 200:  Loss:     0.8482 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 300:  Loss:     0.8432 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 400:  Loss:     0.8121 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 500:  Loss:     0.8351 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 600:  Loss:     0.7670 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 700:  Loss:     0.9219 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 730:  Loss:     0.8274 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 1:  Loss:     0.7511 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 100:  Loss:     0.7769 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 200:  Loss:     0.8215 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 300:  Loss:     0.8254 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 400:  Loss:     0.8250 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 500:  Loss:     0.8522 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 600:  Loss:     0.7654 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 700:  Loss:     0.8978 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 730:  Loss:     0.8371 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 1:  Loss:     0.7471 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 100:  Loss:     0.7791 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 200:  Loss:     0.7954 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 300:  Loss:     0.8745 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 400:  Loss:     0.7978 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 500:  Loss:     0.7993 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 600:  Loss:     0.8008 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 700:  Loss:     0.8280 Validation Accuracy: 0.000000
# Epoch 81, Yelp Batch 730:  Loss:     0.7906 Validation Accuracy: 0.000000
# Epoch 91, Yelp Batch 1:  Loss:     0.7563 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 100:  Loss:     0.7767 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 200:  Loss:     0.8159 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 300:  Loss:     0.8232 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 400:  Loss:     0.7976 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 500:  Loss:     0.7983 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 600:  Loss:     0.8074 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 700:  Loss:     0.8781 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 730:  Loss:     0.7957 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 1:  Loss:     0.8012 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 100:  Loss:     0.8389 Validation Accuracy: 0.300000
# Epoch  1, Yelp Batch 200:  Loss:     0.7981 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 300:  Loss:     0.8556 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 400:  Loss:     0.7811 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 500:  Loss:     0.7977 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 600:  Loss:     0.7403 Validation Accuracy: 0.200000
# Epoch  1, Yelp Batch 700:  Loss:     0.7510 Validation Accuracy: 0.100000
# Epoch  1, Yelp Batch 730:  Loss:     0.7894 Validation Accuracy: 0.500000
# Epoch 11, Yelp Batch 1:  Loss:     0.8348 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 100:  Loss:     0.8658 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 200:  Loss:     0.8757 Validation Accuracy: 0.200000
# Epoch 11, Yelp Batch 300:  Loss:     0.8046 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 400:  Loss:     0.8230 Validation Accuracy: 0.300000
# Epoch 11, Yelp Batch 500:  Loss:     0.8372 Validation Accuracy: 0.100000
# Epoch 11, Yelp Batch 600:  Loss:     0.7586 Validation Accuracy: 0.400000
# Epoch 11, Yelp Batch 700:  Loss:     0.8594 Validation Accuracy: 0.500000
# Epoch 11, Yelp Batch 730:  Loss:     0.7584 Validation Accuracy: 0.300000
# Epoch 21, Yelp Batch 1:  Loss:     0.8328 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 100:  Loss:     0.8217 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 200:  Loss:     0.7763 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 300:  Loss:     0.8287 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 400:  Loss:     0.8213 Validation Accuracy: 0.100000
# Epoch 21, Yelp Batch 500:  Loss:     0.8108 Validation Accuracy: 0.200000
# Epoch 21, Yelp Batch 600:  Loss:     0.8009 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 700:  Loss:     0.8147 Validation Accuracy: 0.400000
# Epoch 21, Yelp Batch 730:  Loss:     0.7582 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 1:  Loss:     0.8251 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 100:  Loss:     0.8104 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 200:  Loss:     0.8130 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 300:  Loss:     0.7894 Validation Accuracy: 0.000000
# Epoch 31, Yelp Batch 400:  Loss:     0.8134 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 500:  Loss:     0.7847 Validation Accuracy: 0.100000
# Epoch 31, Yelp Batch 600:  Loss:     0.8194 Validation Accuracy: 0.500000
# Epoch 31, Yelp Batch 700:  Loss:     0.7695 Validation Accuracy: 0.200000
# Epoch 31, Yelp Batch 730:  Loss:     0.8054 Validation Accuracy: 0.600000
# Epoch 41, Yelp Batch 1:  Loss:     0.8039 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 100:  Loss:     0.8069 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 200:  Loss:     0.7577 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 300:  Loss:     0.8657 Validation Accuracy: 0.300000
# Epoch 41, Yelp Batch 400:  Loss:     0.7834 Validation Accuracy: 0.100000
# Epoch 41, Yelp Batch 500:  Loss:     0.8619 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 600:  Loss:     0.7327 Validation Accuracy: 0.200000
# Epoch 41, Yelp Batch 700:  Loss:     0.8446 Validation Accuracy: 0.600000
# Epoch 41, Yelp Batch 730:  Loss:     0.7761 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 1:  Loss:     0.8499 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 100:  Loss:     0.8596 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 200:  Loss:     0.8426 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 300:  Loss:     0.7797 Validation Accuracy: 0.000000
# Epoch 51, Yelp Batch 400:  Loss:     0.7887 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 500:  Loss:     0.8410 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 600:  Loss:     0.7577 Validation Accuracy: 0.200000
# Epoch 51, Yelp Batch 700:  Loss:     0.7966 Validation Accuracy: 0.300000
# Epoch 51, Yelp Batch 730:  Loss:     0.7440 Validation Accuracy: 0.000000
# Epoch 61, Yelp Batch 1:  Loss:     0.7971 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 100:  Loss:     0.8315 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 200:  Loss:     0.7485 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 300:  Loss:     0.8116 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 400:  Loss:     0.7776 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 500:  Loss:     0.8282 Validation Accuracy: 0.100000
# Epoch 61, Yelp Batch 600:  Loss:     0.7411 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 700:  Loss:     0.7631 Validation Accuracy: 0.200000
# Epoch 61, Yelp Batch 730:  Loss:     0.7445 Validation Accuracy: 0.000000
# Epoch 71, Yelp Batch 1:  Loss:     0.7894 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 100:  Loss:     0.8721 Validation Accuracy: 0.300000
# Epoch 71, Yelp Batch 200:  Loss:     0.8031 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 300:  Loss:     0.8413 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 400:  Loss:     0.8168 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 500:  Loss:     0.8278 Validation Accuracy: 0.100000
# Epoch 71, Yelp Batch 600:  Loss:     0.8336 Validation Accuracy: 0.600000
# Epoch 71, Yelp Batch 700:  Loss:     0.7670 Validation Accuracy: 0.200000
# Epoch 71, Yelp Batch 730:  Loss:     0.8079 Validation Accuracy: 0.400000
# Epoch 81, Yelp Batch 1:  Loss:     0.8190 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 100:  Loss:     0.7512 Validation Accuracy: 0.000000
# Epoch 81, Yelp Batch 200:  Loss:     0.7731 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 300:  Loss:     0.8570 Validation Accuracy: 0.100000
# Epoch 81, Yelp Batch 400:  Loss:     0.8394 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 500:  Loss:     0.8050 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 600:  Loss:     0.7807 Validation Accuracy: 0.300000
# Epoch 81, Yelp Batch 700:  Loss:     0.7723 Validation Accuracy: 0.200000
# Epoch 81, Yelp Batch 730:  Loss:     0.7899 Validation Accuracy: 0.300000
# Epoch 91, Yelp Batch 1:  Loss:     0.7789 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 100:  Loss:     0.7861 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 200:  Loss:     0.7960 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 300:  Loss:     0.8117 Validation Accuracy: 0.100000
# Epoch 91, Yelp Batch 400:  Loss:     0.8040 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 500:  Loss:     0.8221 Validation Accuracy: 0.200000
# Epoch 91, Yelp Batch 600:  Loss:     0.7920 Validation Accuracy: 0.500000
# Epoch 91, Yelp Batch 700:  Loss:     0.8043 Validation Accuracy: 0.400000
# Epoch 91, Yelp Batch 730:  Loss:     0.7672 Validation Accuracy: 0.400000

# %% [markdown]
# ## Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset. This will be your final accuracy.

# %%
training_imgs.shape
